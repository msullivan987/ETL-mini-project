# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Store filepath in a variable
csv_path= "netflix_titles.csv"
netflix_df = pd.read_csv(csv_path)
netflix_df.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80125979  Movie                             #realityhigh
# 2  70304989  Movie                                 Automata
# 3  70304990  Movie                              Good People
# 4  70299204  Movie                  Kidnapping Mr. Heineken
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1          Fernando Lebrija
# 2               Gabe Ibáñez
# 3         Henrik Ruben Genz
# 4          Daniel Alfredson
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 2  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 3  James Franco, Kate Hudson, Tom Wilkinson, Omar...
# 4  Jim Sturgess, Sam Worthington, Ryan Kwanten, A...
#
#                                              country date_added  release_year  \
# ...

# %%
new_netflix_df = netflix_df[["show_id","title","release_year","rating"]].copy()
new_netflix_df
# Out:
#        show_id                                    title  release_year rating
# 0     81145628  Norm of the North: King Sized Adventure          2019  TV-PG
# 1     80125979                             #realityhigh          2017  TV-14
# 2     70304989                                 Automata          2014      R
# 3     70304990                              Good People          2014      R
# 4     70299204                  Kidnapping Mr. Heineken          2015      R
# ...        ...                                      ...           ...    ...
# 1919  80097468                             The Bad Kids          2016  TV-MA
# 1920  80085438                          Frank and Cindy          2007  TV-MA
# 1921  80085439                          Frank and Cindy          2015      R
# 1922  80011846                                  Iverson          2014     NR
# 1923  80064521      Jeremy Scott: The People's Designer          2015  PG-13
#
# [1924 rows x 4 columns]

# %%
new_netflix_df["title"] = new_netflix_df["title"].apply(lambda x: x.lower())
new_netflix_df
# Out:
#        show_id                                    title  release_year rating
# 0     81145628  norm of the north: king sized adventure          2019  TV-PG
# 1     80125979                             #realityhigh          2017  TV-14
# 2     70304989                                 automata          2014      R
# 3     70304990                              good people          2014      R
# 4     70299204                  kidnapping mr. heineken          2015      R
# ...        ...                                      ...           ...    ...
# 1919  80097468                             the bad kids          2016  TV-MA
# 1920  80085438                          frank and cindy          2007  TV-MA
# 1921  80085439                          frank and cindy          2015      R
# 1922  80011846                                  iverson          2014     NR
# 1923  80064521      jeremy scott: the people's designer          2015  PG-13
#
# [1924 rows x 4 columns]

# %%
#Connecting to local database
rds_connection_string = "postgres:postgres@localhost:5432/bechdel_netflix_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['netflix_data']

# %%
new_netflix_df.to_sql(name='netflix_data', con=engine, if_exists='append', index=False)
